# %%
import pandas as pd
import numpy as np

# %%
reg_df = pd.read_csv('fake_reg_hidden_data.csv')
classif_df = pd.read_csv('fake_classif_hidden_data.csv')

# %%
reg_df.tail(2)
# Out:
#                          Doctor Name      City      Specialization  \
# 41          Dr. M Badar Ud Din Zafir    MULTAN  Orthopedic Surgeon
# 42  Assoc. Prof. Dr. Kaya Husnu Akan  ISTANBUL  Orthopedic Surgeon
#
#                                Doctor Qualification  Experience(Years)  \
# 41  MBBS, FCPS (Orthopedic Surgery), MCPS (Surgery)                 19
# 42                                               MD                 27
#
#     Total_Reviews  Patient Satisfaction Rate(%age)  \
# 41             90                              100
# 42              0                               94
#
#     Avg Time to Patients(mins)  Wait Time(mins)  \
# 41                          14                6
# 42                          14               11
#
#                                     Hospital Address  \
# 41           CGO Clinic, New Shalimar Colony, Multan
# 42  Okan University Hospital, Tuzla Turkey, Istanbul
#
#                                          Doctors Link  Fee(PKR)
# ...

# %%
classif_df.head(2)
# Out:
#          Doctor Name        City     Specialization  \
# 0   Dr. Umair Hafeez  GUJRANWALA     Ent Specialist
# 1  Dr. Haris Shakeel   RAJAN-PUR  General Physician
#
#                          Doctor Qualification  Experience(Years)  \
# 0   MBBS , FCPS ( Otorhinolaryngologic ENT )                   6
# 1                                        MBBS                  1
#
#    Total_Reviews  Patient Satisfaction Rate(%age)  Avg Time to Patients(mins)  \
# 0             11                              100                          19
# 1              0                               94                          14
#
#    Wait Time(mins)                             Hospital Address  \
# 0                6  Central Hospital, Jinnah Colony, Gujranwala
# 1               11                         No Address Available
#
#                                         Doctors Link Fee Category
# 0  https://www.marham.pk/doctors/gujranwala/ent-s...    Expensive
# ...
